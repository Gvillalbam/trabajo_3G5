# %% [markdown]
# # Pasos Iniciales
# # Ejecutar "conda env create -f environment.yml" en la terminal
# # Cuando Finalice ejecutar "conda init" al finalizar cerrar la terminal
# # Abrir la terminal nuevamente y ejecutar "conda activate TAREA_3_A_1"
# # Ejecutar "python -m ipykernel install --user --name TAREA_3_A_1 --display-name "Python (TAREA_3_A_1)" para poder visualizar el kernel
# # Dar clic sobre Seleccionar Kernel, en el buscador seleccionar entornos de Python y a su vez el entorno TAREA_3_A_1
